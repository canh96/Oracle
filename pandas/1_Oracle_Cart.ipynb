# %%
# conda install -c conda-forge cx_Oracle
# pip install cx_Oracle

# %%
import cx_Oracle
import pandas as pd

# %%
dsn = cx_Oracle.makedsn("localhost", 1521, "xe")
dsn
# Out:
# '(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=xe)))'

# %%
conn = cx_Oracle.connect("busan_06", "dbdb", dsn)
conn
# Out:
# <cx_Oracle.Connection to busan_06@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=xe)))>

# %%
cursor = conn.cursor()
cursor
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to busan_06@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=xe)))>>

# %%
sql = """ Select * 
From Cart """
sql
# Out:
# ' Select * \nFrom Cart '

# %%
cursor.execute(sql)
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to busan_06@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=xe)))>>

# %%
row = cursor.fetchall()
row
# Out:
# [('a001', '2005040100001', 'P101000001', 5),
#  ('a001', '2005040100001', 'P201000018', 16),
#  ('a001', '2005040100001', 'P302000003', 7),
#  ('t001', '2005040100002', 'P302000004', 2),
#  ('t001', '2005040100002', 'P101000002', 2),
#  ('w001', '2005040100003', 'P201000019', 2),
#  ('w001', '2005040100003', 'P302000005', 9),
#  ('w001', '2005040100003', 'P201000020', 21),
#  ('w001', '2005040100003', 'P101000003', 3),
#  ('r001', '2005040500001', 'P302000006', 2),
#  ('r001', '2005040500001', 'P101000004', 2),
#  ('r001', '2005040500001', 'P201000021', 2),
#  ('q001', '2005040500002', 'P302000011', 11),
#  ('q001', '2005040500002', 'P202000001', 12),
#  ('q001', '2005040500002', 'P101000005', 4),
#  ('p001', '2005040600001', 'P101000006', 2),
#  ('p001', '2005040600001', 'P202000002', 2),
#  ('o001', '2005040600002', 'P302000013', 9),
#  ('o001', '2005040600002', 'P202000003', 9),
#  ('o001', '2005040600002', 'P102000001', 6),
#  ('f001', '2005040800001', 'P302000014', 2),
#  ('f001', '2005040800001', 'P102000002', 2),
#  ('f001', '2005040800001', 'P202000004', 2),
#  ('m001', '2005040800002', 'P302000015', 8),
#  ('m001', '2005040800002', 'P202000005', 8),
#  ('m001', '2005040800002', 'P102000003', 9),
#  ('l001', '2005041000001', 'P302000016', 2),
#  ('l001', '2005041000001', 'P102000004', 2),
#  ('l001', '2005041000001', 'P202000006', 2),
#  ('f001', '2005041000002', 'P202000007', 7),
#  ('f001', '2005041000002', 'P102000005', 8),
#  ('f001', '2005041000002', 'P302000021', 7),
#  ('j001', '2005041200001', 'P302000022', 2),
#  ('j001', '2005041200001', 'P202000008', 2),
#  ('j001', '2005041200001', 'P102000006', 2),
#  ('j001', '2005041200001', 'P202000009', 6),
#  ('m001', '2005041200002', 'P102000007', 7),
#  ('m001', '2005041200002', 'P302000023', 6),
#  ('m001', '2005041200002', 'P202000010', 2),
#  ('f001', '2005041500001', 'P201000001', 2),
#  ('f001', '2005041500001', 'P302000001', 2),
#  ('j001', '2005041500002', 'P202000011', 5),
#  ('j001', '2005041500002', 'P201000002', 5),
#  ('j001', '2005041500002', 'P302000002', 5),
#  ('f001', '2005041600001', 'P302000003', 2),
#  ('f001', '2005041600001', 'P201000003', 2),
#  ('f001', '2005041600001', 'P202000012', 2),
#  ('e001', '2005041600002', 'P302000004', 4),
#  ('e001', '2005041600002', 'P201000004', 3),
#  ('e001', '2005041600002', 'P202000013', 4),
#  ('d001', '2005041800001', 'P302000005', 2),
#  ('d001', '2005041800001', 'P201000005', 2),
#  ('d001', '2005041800001', 'P202000014', 2),
#  ('c001', '2005041800002', 'P302000006', 3),
#  ('c001', '2005041800002', 'P201000006', 1),
#  ('c001', '2005041800002', 'P202000015', 3),
#  ('b001', '2005042000001', 'P302000011', 2),
#  ('b001', '2005042000001', 'P201000007', 2),
#  ('b001', '2005042000001', 'P202000016', 2),
#  ('b001', '2005042000001', 'P202000017', 1),
#  ('b001', '2005042000001', 'P201000008', 5),
#  ('c001', '2005042000002', 'P202000018', 2),
#  ('c001', '2005042000002', 'P201000009', 2),
#  ('c001', '2005042000002', 'P202000019', 2),
#  ('c001', '2005042000002', 'P201000010', 4),
#  ('c001', '2005042000002', 'P202000020', 2),
#  ('x001', '2005042400001', 'P201000011', 2),
#  ('x001', '2005042400001', 'P202000021', 4),
#  ('x001', '2005042400001', 'P201000012', 3),
#  ('e001', '2005042400002', 'P301000001', 2),
#  ('e001', '2005042400002', 'P201000013', 2),
#  ('e001', '2005042400002', 'P301000002', 5),
#  ('e001', '2005042400002', 'P201000014', 13),
#  ('c001', '2005042800001', 'P301000003', 2),
#  ('c001', '2005042800001', 'P201000015', 2),
#  ('b001', '2005042800002', 'P302000001', 6),
#  ('b001', '2005042800002', 'P201000016', 15),
#  ('b001', '2005042800002', 'P302000002', 2),
#  ('b001', '2005042800002', 'P201000017', 2),
#  ('b001', '2005050100001', 'P201000013', 5),
#  ('b001', '2005050100001', 'P301000002', 5),
#  ('c001', '2005050100002', 'P301000003', 6),
#  ('c001', '2005050100002', 'P201000014', 3),
#  ('c001', '2005050100002', 'P201000015', 7),
#  ('d001', '2005050300001', 'P302000001', 4),
#  ('d001', '2005050300001', 'P302000002', 3),
#  ('e001', '2005050300002', 'P201000016', 8),
#  ('e001', '2005050300002', 'P201000017', 21),
#  ('g001', '2005050500001', 'P302000003', 4),
#  ('g001', '2005050500001', 'P201000018', 11),
#  ('g001', '2005050500001', 'P302000004', 3),
#  ('a001', '2005050500002', 'P201000019', 12),
#  ('a001', '2005050700001', 'P302000005', 5),
#  ('a001', '2005050700001', 'P101000001', 3),
#  ('a001', '2005050700001', 'P101000002', 1),
#  ('b001', '2005050700002', 'P201000020', 2),
#  ('b001', '2005050700002', 'P302000006', 6),
#  ('b001', '2005050700002', 'P302000011', 7),
#  ('c001', '2005051000001', 'P201000021', 5),
#  ('c001', '2005051000001', 'P101000003', 2),
#  ('c001', '2005051000001', 'P101000004', 4),
#  ('d001', '2005051000002', 'P202000001', 6),
#  ('d001', '2005051000002', 'P302000012', 8),
#  ('d001', '2005051000002', 'P302000013', 3),
#  ('d001', '2005051000002', 'P101000005', 5),
#  ('d001', '2005051000002', 'P202000002', 7),
#  ('f001', '2005051200001', 'P101000006', 6),
#  ('f001', '2005051200001', 'P202000003', 8),
#  ('f001', '2005051200001', 'P302000014', 4),
#  ('f001', '2005051200001', 'P302000015', 5),
#  ('f001', '2005051200001', 'P102000001', 1),
#  ('g001', '2005051300001', 'P202000004', 9),
#  ('g001', '2005051300001', 'P102000002', 2),
#  ('g001', '2005051300001', 'P202000005', 11),
#  ('g001', '2005051300001', 'P302000016', 6),
#  ('g001', '2005051300001', 'P302000021', 3),
#  ('i001', '2005051500001', 'P102000003', 3),
#  ('i001', '2005051500001', 'P202000006', 12),
#  ('j001', '2005051600001', 'P102000004', 4),
#  ('j001', '2005051600001', 'P202000007', 17),
#  ('j001', '2005051600001', 'P302000022', 1),
#  ('k001', '2005051600002', 'P302000023', 3),
#  ('k001', '2005051600002', 'P102000005', 5),
#  ('k001', '2005051600002', 'P202000008', 21),
#  ('k001', '2005051600002', 'P102000006', 6),
#  ('k001', '2005051600002', 'P202000009', 13),
#  ('l001', '2005051800001', 'P302000001', 4),
#  ('l001', '2005051800001', 'P302000002', 6),
#  ('m001', '2005051800002', 'P102000007', 3),
#  ('m001', '2005051800002', 'P202000010', 23),
#  ('m001', '2005051800002', 'P201000001', 5),
#  ('m001', '2005051800002', 'P202000011', 25),
#  ('m001', '2005051800002', 'P302000003', 7),
#  ('m001', '2005051800002', 'P302000004', 2),
#  ('o001', '2005052100001', 'P201000002', 2),
#  ('o001', '2005052100001', 'P202000012', 5),
#  ('o001', '2005052100001', 'P201000003', 5),
#  ('p001', '2005052100002', 'P202000013', 7),
#  ('p001', '2005052100002', 'P302000005', 3),
#  ('p001', '2005052100002', 'P302000006', 1),
#  ('p001', '2005052100002', 'P201000004', 6),
#  ('p001', '2005052100002', 'P202000014', 6),
#  ('r001', '2005052400001', 'P201000005', 2),
#  ('r001', '2005052400001', 'P202000015', 5),
#  ('r001', '2005052400001', 'P302000011', 4),
#  ('s001', '2005052500001', 'P302000012', 2),
#  ('s001', '2005052500001', 'P201000006', 3),
#  ('s001', '2005052500001', 'P202000016', 4),
#  ('t001', '2005052500002', 'P201000007', 1),
#  ('t001', '2005052500002', 'P202000017', 3),
#  ('t001', '2005052500002', 'P201000008', 6),
#  ('t001', '2005052500002', 'P202000018', 2),
#  ('v001', '2005052800001', 'P201000009', 3),
#  ('v001', '2005052800001', 'P202000019', 1),
#  ('w001', '2005052900001', 'P201000010', 2),
#  ('w001', '2005052900001', 'P202000020', 9),
#  ('w001', '2005052900001', 'P201000011', 3),
#  ('x001', '2005052900002', 'P202000021', 8),
#  ('x001', '2005052900002', 'P201000012', 4),
#  ('x001', '2005052900002', 'P301000001', 7),
#  ('a001', '2005060500001', 'P302000013', 2),
#  ('a001', '2005060500001', 'P302000014', 11),
#  ('a001', '2005060500001', 'P302000015', 2),
#  ('b001', '2005060600001', 'P302000016', 9),
#  ('b001', '2005060600001', 'P302000021', 2),
#  ('b001', '2005060600001', 'P302000022', 8),
#  ('c001', '2005061200001', 'P302000023', 2),
#  ('c001', '2005061200001', 'P302000001', 7),
#  ('d001', '2005061300001', 'P302000002', 2),
#  ('d001', '2005061300001', 'P302000003', 6),
#  ('e001', '2005061300002', 'P302000004', 2),
#  ('e001', '2005061300002', 'P302000005', 5),
#  ('e001', '2005062100001', 'P302000006', 2),
#  ('e001', '2005062100001', 'P302000011', 4),
#  ('f001', '2005062100002', 'P302000012', 2),
#  ('f001', '2005062500001', 'P302000013', 3),
#  ('f001', '2005062500001', 'P302000014', 2),
#  ('f001', '2005062500001', 'P302000015', 1),
#  ('b001', '2005070100001', 'P201000013', 5),
#  ('b001', '2005070100001', 'P301000002', 5),
#  ('c001', '2005070100002', 'P301000003', 6),
#  ('c001', '2005070100002', 'P201000014', 3),
#  ('c001', '2005070100002', 'P201000015', 7),
#  ('d001', '2005070300001', 'P302000001', 4),
#  ('d001', '2005070300001', 'P302000002', 3),
#  ('e001', '2005070300002', 'P201000016', 8),
#  ('e001', '2005070300002', 'P201000017', 21),
#  ('g001', '2005070800001', 'P101000001', 3),
#  ('g001', '2005070800001', 'P101000002', 1),
#  ('r001', '2005070800002', 'P101000003', 2),
#  ('h001', '2005071100001', 'P101000005', 5),
#  ('r001', '2005071100002', 'P101000006', 6),
#  ('i001', '2005071900001', 'P102000001', 1),
#  ('i001', '2005071900001', 'P102000002', 2),
#  ('i001', '2005071900001', 'P102000003', 3),
#  ('u001', '2005071900002', 'P102000004', 4),
#  ('u001', '2005071900002', 'P102000005', 5),
#  ('j001', '2005072800001', 'P102000006', 6),
#  ('j001', '2005072800001', 'P102000003', 3),
#  ('q001', '2005072800002', 'P102000004', 4),
#  ('q001', '2005072800002', 'P102000005', 5),
#  ('c001', '2005072800003', 'P301000003', 2),
#  ('c001', '2005072800003', 'P201000015', 2),
#  ('b001', '2005072800004', 'P302000001', 6),
#  ('b001', '2005072800004', 'P201000016', 15),
#  ('b001', '2005072800004', 'P302000002', 2),
#  ('b001', '2005072800004', 'P201000017', 2)]

# %%
colname = cursor.description
colname
# Out:
# [('CART_MEMBER', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 15, 15, None, None, 0),
#  ('CART_NO', <cx_Oracle.DbType DB_TYPE_CHAR>, 13, 13, None, None, 0),
#  ('CART_PROD', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 10, 10, None, None, 0),
#  ('CART_QTY', <cx_Oracle.DbType DB_TYPE_NUMBER>, 9, None, 8, 0, 0)]

# %%
cursor.close()

# %%
conn.close()

# %%
# 컬럼 뽑아오기
col = []
for tp in colname:
    print(tp[0])
    col.append(tp[0])
    
col
# Out:
# CART_MEMBER
# CART_NO
# CART_PROD
# CART_QTY
# ['CART_MEMBER', 'CART_NO', 'CART_PROD', 'CART_QTY']

# %%
pd.DataFrame(row, columns=col)
# Out:
#     CART_MEMBER        CART_NO   CART_PROD  CART_QTY
# 0          a001  2005040100001  P101000001         5
# 1          a001  2005040100001  P201000018        16
# 2          a001  2005040100001  P302000003         7
# 3          t001  2005040100002  P302000004         2
# 4          t001  2005040100002  P101000002         2
# ..          ...            ...         ...       ...
# 202        c001  2005072800003  P201000015         2
# 203        b001  2005072800004  P302000001         6
# 204        b001  2005072800004  P201000016        15
# 205        b001  2005072800004  P302000002         2
# 206        b001  2005072800004  P201000017         2
#
# [207 rows x 4 columns]
